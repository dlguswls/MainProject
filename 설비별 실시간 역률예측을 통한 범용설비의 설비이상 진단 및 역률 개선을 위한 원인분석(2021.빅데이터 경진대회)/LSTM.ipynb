# %% [markdown]
# # 공기압축기_선박엔진

# %% [markdown]
# # 설비명별 데이터프레임 생성

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
import matplotlib.font_manager as fm 

font_fname = 'C:/Windows/Fonts/Malgun.ttf' #적용할 폰트
font_family = fm.FontProperties(fname=font_fname).get_name() #폰트 설정
plt.rcParams["font.family"] = font_family  #폰트 적용

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
os.chdir(r"C:\Users\user\Desktop\산공 빅데이터 경진대회")

# %%
raw_data = pd.read_csv("공기압축기_선박엔진.csv")

# %%
raw_data.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 SVC_NAME  DEVICE_ID  \
# 0      6338880             0               0      SOH       1338
# 1      6338881             1               1      SOH       1338
# 2      6338882             2               2      SOH       1338
# 3      6338883             3               3      SOH       1338
# 4      6338884             4               4      SOH       1338
# 5      6338885             5               5      SOH       1338
# 6      6338886             6               6      SOH       1338
# 7      6338887             7               7      SOH       1338
# 8      6338888             8               8      SOH       1338
# 9      6338889             9               9      SOH       1338
# 10     6338890            10              10      SOH       1338
# 11     6338891            11              11      SOH       1338
# 12     6338892            12              12      SOH       1338
# 13     6338893            13              13      SOH       1338
# 14     6338894            14              14      SOH       1338
# 15     6338895            15              15      SOH       1338
# 16     6338896            16              16      SOH       1338
# 17     6338897            17              17      SOH       1338
# 18     6338898            18              18      SOH       1338
# 19     6338899            19              19      SOH       1338
#
#     DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR LOCATION COMPANY_TYPE  ...  \
# 0              1       CO-295            1981   경북 고령군           제조  ...
# 1              1       CO-295            1981   경북 고령군           제조  ...
# 2              1       CO-295            1981   경북 고령군           제조  ...
# 3              1       CO-295            1981   경북 고령군           제조  ...
# 4              1       CO-295            1981   경북 고령군           제조  ...
# 5              1       CO-295            1981   경북 고령군           제조  ...
# 6              1       CO-295            1981   경북 고령군           제조  ...
# 7              1       CO-295            1981   경북 고령군           제조  ...
# 8              1       CO-295            1981   경북 고령군           제조  ...
# 9              1       CO-295            1981   경북 고령군           제조  ...
# 10             1       CO-295            1981   경북 고령군           제조  ...
# 11             1       CO-295            1981   경북 고령군           제조  ...
# 12             1       CO-295            1981   경북 고령군           제조  ...
# 13             1       CO-295            1981   경북 고령군           제조  ...
# 14             1       CO-295            1981   경북 고령군           제조  ...
# 15             1       CO-295            1981   경북 고령군           제조  ...
# 16             1       CO-295            1981   경북 고령군           제조  ...
# 17             1       CO-295            1981   경북 고령군           제조  ...
# 18             1       CO-295            1981   경북 고령군           제조  ...
# 19             1       CO-295            1981   경북 고령군           제조  ...
#
#    facility_vendor facility_year  facility_capacity facility_volt ITEM_NAME  \
# 0      artlascopco          2004                 86           380     누적전력량
# 1      artlascopco          2004                 86           380        온도
# 2      artlascopco          2004                 86           380     상전압평균
# 3      artlascopco          2004                 86           380    선간전압평균
# 4      artlascopco          2004                 86           380   전압고조파평균
# 5      artlascopco          2004                 86           380      전류평균
# 6      artlascopco          2004                 86           380   전류고조파평균
# 7      artlascopco          2004                 86           380      역률평균
# 8      artlascopco          2004                 86           380    무효전력평균
# 9      artlascopco          2004                 86           380       주파수
# 10     artlascopco          2004                 86           380    유효전력평균
# 11     artlascopco          2004                 86           380       주파수
# 12     artlascopco          2004                 86           380      전류평균
# 13     artlascopco          2004                 86           380     상전압평균
# 14     artlascopco          2004                 86           380        온도
# 15     artlascopco          2004                 86           380    무효전력평균
# 16     artlascopco          2004                 86           380   전류고조파평균
# 17     artlascopco          2004                 86           380    유효전력평균
# 18     artlascopco          2004                 86           380   전압고조파평균
# 19     artlascopco          2004                 86           380     누적전력량
#
#        ITEM_VALUE            TIMESTAMP 역률평균_LABEL  전류고조파평균_LABEL  \
# 0   270288.200000  2020-10-22 00:00:22         정상             정상
# 1       28.125000  2020-10-22 00:00:22         정상             정상
# 2      223.500000  2020-10-22 00:00:22         정상             정상
# 3      387.250000  2020-10-22 00:00:22         정상             정상
# 4        4.817708  2020-10-22 00:00:22         정상             정상
# 5       70.500000  2020-10-22 00:00:22         정상             정상
# 6        5.891927  2020-10-22 00:00:22         정상             정상
# 7        0.948331  2020-10-22 00:00:22         정상             정상
# 8    14954.000000  2020-10-22 00:00:22         정상             정상
# 9       59.872740  2020-10-22 00:00:22         정상             정상
# 10   44696.000000  2020-10-22 00:00:22         정상             정상
# 11      59.863403  2020-10-22 00:01:22         정상             정상
# 12      31.822916  2020-10-22 00:01:22         정상             정상
# 13     223.500000  2020-10-22 00:01:22         정상             정상
# 14      28.125000  2020-10-22 00:01:22         정상             정상
# 15    9604.500000  2020-10-22 00:01:22         정상             정상
# 16       6.510417  2020-10-22 00:01:22         정상             정상
# 17   19313.000000  2020-10-22 00:01:22         정상             정상
# 18       4.817708  2020-10-22 00:01:22         정상             정상
# 19  270840.156000  2020-10-22 00:01:22         정상             정상
#
#     전압고조파평균_LABEL
# 0              주의
# 1              주의
# 2              주의
# 3              주의
# 4              주의
# 5              주의
# 6              주의
# 7              주의
# 8              주의
# 9              주의
# 10             주의
# 11             주의
# 12             주의
# 13             주의
# 14             주의
# 15             주의
# 16             주의
# 17             주의
# 18             주의
# 19             주의
#
# [20 rows x 27 columns]

# %%
data_295 = raw_data[raw_data['COMPANY_NAME'] == 'CO-295']

# %%
data_295['facility_name'].value_counts()
# Out:
# 컴프레서_3    1663224
# 컴프레서_2    1663200
# 컴프레서_1    1509725
# Name: facility_name, dtype: int64

# %%
comp_1 = data_295[data_295['facility_name'] == '컴프레서_1']

# %%
comp_1
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 SVC_NAME  DEVICE_ID  \
# 0           6338880             0               0      SOH       1338
# 1           6338881             1               1      SOH       1338
# 2           6338882             2               2      SOH       1338
# 3           6338883             3               3      SOH       1338
# 4           6338884             4               4      SOH       1338
# ...             ...           ...             ...      ...        ...
# 1509720     7848600       1509720         1509720      SOH       1338
# 1509721     7848601       1509721         1509721      SOH       1338
# 1509722     7848602       1509722         1509722      SOH       1338
# 1509723     7848603       1509723         1509723      SOH       1338
# 1509724     7848604       1509724         1509724      SOH       1338
#
#          DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR LOCATION COMPANY_TYPE  ...  \
# 0                   1       CO-295            1981   경북 고령군           제조  ...
# 1                   1       CO-295            1981   경북 고령군           제조  ...
# 2                   1       CO-295            1981   경북 고령군           제조  ...
# 3                   1       CO-295            1981   경북 고령군           제조  ...
# 4                   1       CO-295            1981   경북 고령군           제조  ...
# ...               ...          ...             ...      ...          ...  ...
# 1509720             1       CO-295            1981   경북 고령군           제조  ...
# 1509721             1       CO-295            1981   경북 고령군           제조  ...
# 1509722             1       CO-295            1981   경북 고령군           제조  ...
# 1509723             1       CO-295            1981   경북 고령군           제조  ...
# 1509724             1       CO-295            1981   경북 고령군           제조  ...
#
#         facility_vendor facility_year  facility_capacity facility_volt  \
# 0           artlascopco          2004                 86           380
# 1           artlascopco          2004                 86           380
# 2           artlascopco          2004                 86           380
# 3           artlascopco          2004                 86           380
# 4           artlascopco          2004                 86           380
# ...                 ...           ...                ...           ...
# 1509720     artlascopco          2004                 86           380
# 1509721     artlascopco          2004                 86           380
# 1509722     artlascopco          2004                 86           380
# 1509723     artlascopco          2004                 86           380
# 1509724     artlascopco          2004                 86           380
#
#         ITEM_NAME     ITEM_VALUE            TIMESTAMP 역률평균_LABEL  \
# 0           누적전력량  270288.200000  2020-10-22 00:00:22         정상
# 1              온도      28.125000  2020-10-22 00:00:22         정상
# 2           상전압평균     223.500000  2020-10-22 00:00:22         정상
# 3          선간전압평균     387.250000  2020-10-22 00:00:22         정상
# 4         전압고조파평균       4.817708  2020-10-22 00:00:22         정상
# ...           ...            ...                  ...        ...
# 1509720    T상유효전력       0.000000  2020-11-22 23:59:35         경고
# 1509721    T상무효전력       0.000000  2020-11-22 23:59:35         경고
# 1509722      T상역률       0.000000  2020-11-22 23:59:35         경고
# 1509723   T상전압고조파       3.125000  2020-11-22 23:59:35         경고
# 1509724   T상전류고조파       0.000000  2020-11-22 23:59:35         경고
#
#          전류고조파평균_LABEL  전압고조파평균_LABEL
# 0                   정상             주의
# 1                   정상             주의
# 2                   정상             주의
# 3                   정상             주의
# 4                   정상             주의
# ...                ...            ...
# 1509720             정상             주의
# 1509721             정상             주의
# 1509722             정상             주의
# 1509723             정상             주의
# 1509724             정상             주의
#
# [1509725 rows x 27 columns]

# %%
col = ['전류평균', '온도', '선간전압평균', '상전압평균', '유효전력평균', '누적전력량', '역률평균', '주파수', '전압고조파평균', '무효전력평균']
comp_clear = comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,:-6]
for i in range(0,len(col)) : 
    values = list(comp_1[comp_1['ITEM_NAME']==col[i]]['ITEM_VALUE'])
    comp_clear[col[i]] = values

comp_clear['TIMESTAMP'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-4])   
comp_clear['역률평균_LABEL'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-3])
comp_clear['전압고조파평균_LABEL'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-1])

# %%
comp_clear = comp_clear.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1'], axis=1)

# %%
comp_clear
# Out:
#         SVC_NAME  DEVICE_ID  DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR  \
# 5            SOH       1338             1       CO-295            1981
# 12           SOH       1338             1       CO-295            1981
# 22           SOH       1338             1       CO-295            1981
# 33           SOH       1338             1       CO-295            1981
# 52           SOH       1338             1       CO-295            1981
# ...          ...        ...           ...          ...             ...
# 1508239      SOH       1338             1       CO-295            1981
# 1508244      SOH       1338             1       CO-295            1981
# 1508257      SOH       1338             1       CO-295            1981
# 1508268      SOH       1338             1       CO-295            1981
# 1508278      SOH       1338             1       CO-295            1981
#
#         LOCATION COMPANY_TYPE COMPANY_CAT MAJOR_PRODUCT  CONTRACT_POWER  ...  \
# 5         경북 고령군           제조         열처리          선박엔진            7000  ...
# 12        경북 고령군           제조         열처리          선박엔진            7000  ...
# 22        경북 고령군           제조         열처리          선박엔진            7000  ...
# 33        경북 고령군           제조         열처리          선박엔진            7000  ...
# 52        경북 고령군           제조         열처리          선박엔진            7000  ...
# ...          ...          ...         ...           ...             ...  ...
# 1508239   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508244   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508257   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508268   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508278   경북 고령군           제조         열처리          선박엔진            7000  ...
#
#               상전압평균   유효전력평균         누적전력량      역률평균        주파수   전압고조파평균  \
# 5        223.500000  44696.0  2.702882e+05  0.948331  59.872740  4.817708
# 12       223.500000  19313.0  2.708402e+05  0.895390  59.863403  4.817708
# 22       223.333328  44907.0  2.714893e+05  0.948258  59.910122  4.785156
# 33       223.583328  46233.0  2.722598e+05  0.948171  59.872740  4.817708
# 52       223.750000  30076.0  2.729348e+05  0.937192  59.891440  4.817708
# ...             ...      ...           ...       ...        ...       ...
# 1508239  227.083328      0.0  1.549272e+07  0.000000  59.882076  3.190104
# 1508244  227.166672      0.0  1.549272e+07  0.000000  59.798140  3.190104
# 1508257  227.000000      0.0  1.549272e+07  0.000000  59.854070  3.125000
# 1508268  226.833328      0.0  1.549272e+07  0.000000  59.816770  3.222656
# 1508278  226.750000      0.0  1.549272e+07  0.000000  59.844740  3.222656
#
#           무효전력평균            TIMESTAMP  역률평균_LABEL  전압고조파평균_LABEL
# 5        14954.0  2020-10-22 00:00:22          정상             주의
# 12        9604.5  2020-10-22 00:01:22          정상             주의
# 22       15036.0  2020-10-22 00:02:22          정상             주의
# 33       15494.0  2020-10-22 00:03:22          정상             주의
# 52       11194.0  2020-10-22 00:04:22          정상             주의
# ...          ...                  ...         ...            ...
# 1508239      0.0  2020-11-22 23:55:35          경고             주의
# 1508244      0.0  2020-11-22 23:56:35          경고             주의
# 1508257      0.0  2020-11-22 23:57:35          경고             주의
# 1508268      0.0  2020-11-22 23:58:35          경고             주의
# 1508278      0.0  2020-11-22 23:59:35          경고             주의
#
# [43135 rows x 31 columns]

# %%
comp_clear.columns
# Out:
# Index(['SVC_NAME', 'DEVICE_ID', 'DEVICE_BD_ID', 'COMPANY_NAME',
#        'ESTABLISH_YEAR', 'LOCATION', 'COMPANY_TYPE', 'COMPANY_CAT',
#        'MAJOR_PRODUCT', 'CONTRACT_POWER', 'BILL_OPTION', 'KEPCO_INFO',
#        'facility_name', 'facility_type_name', 'facility_vendor',
#        'facility_year', 'facility_capacity', 'facility_volt', '전류평균', '온도',
#        '선간전압평균', '상전압평균', '유효전력평균', '누적전력량', '역률평균', '주파수', '전압고조파평균',
#        '무효전력평균', 'TIMESTAMP', '역률평균_LABEL', '전압고조파평균_LABEL'],
#       dtype='object')

# %%
comp_1_one = comp_clear[['전류평균','역률평균','온도','전압고조파평균','TIMESTAMP']]

# %%
comp_1_one
# Out:
#               전류평균      역률평균      온도   전압고조파평균            TIMESTAMP
# 5        70.500000  0.948331  28.125  4.817708  2020-10-22 00:00:22
# 12       31.822916  0.895390  28.125  4.817708  2020-10-22 00:01:22
# 22       70.927086  0.948258  28.125  4.785156  2020-10-22 00:02:22
# 33       72.843750  0.948171  27.500  4.817708  2020-10-22 00:03:22
# 52       47.104168  0.937192  28.750  4.817708  2020-10-22 00:04:22
# ...            ...       ...     ...       ...                  ...
# 1508239   0.000000  0.000000  16.875  3.190104  2020-11-22 23:55:35
# 1508244   0.000000  0.000000  16.875  3.190104  2020-11-22 23:56:35
# 1508257   0.000000  0.000000  17.500  3.125000  2020-11-22 23:57:35
# 1508268   0.000000  0.000000  16.875  3.222656  2020-11-22 23:58:35
# 1508278   0.000000  0.000000  17.500  3.222656  2020-11-22 23:59:35
#
# [43135 rows x 5 columns]

# %%
comp_1_one['TIME'] = pd.to_datetime(comp_1_one['TIMESTAMP'])
comp_1_one.drop('TIMESTAMP', axis = 1, inplace=True)
comp_1_one.set_index('TIME', inplace=True)

# %%
comp_1_one
# Out:
#                           전류평균      역률평균      온도   전압고조파평균
# TIME
# 2020-10-22 00:00:22  70.500000  0.948331  28.125  4.817708
# 2020-10-22 00:01:22  31.822916  0.895390  28.125  4.817708
# 2020-10-22 00:02:22  70.927086  0.948258  28.125  4.785156
# 2020-10-22 00:03:22  72.843750  0.948171  27.500  4.817708
# 2020-10-22 00:04:22  47.104168  0.937192  28.750  4.817708
# ...                        ...       ...     ...       ...
# 2020-11-22 23:55:35   0.000000  0.000000  16.875  3.190104
# 2020-11-22 23:56:35   0.000000  0.000000  16.875  3.190104
# 2020-11-22 23:57:35   0.000000  0.000000  17.500  3.125000
# 2020-11-22 23:58:35   0.000000  0.000000  16.875  3.222656
# 2020-11-22 23:59:35   0.000000  0.000000  17.500  3.222656
#
# [43135 rows x 4 columns]

# %%
comp_1_one['2020-10-22'].plot()
# Out:
# <AxesSubplot:xlabel='TIME'>

# %%
features = comp_1_one[['전류평균','역률평균','온도','전압고조파평균']]

# %%
features.plot(subplots=True)
plt.show()

# %%
comp_1_one.value_counts()
# Out:
# 전류평균        역률평균      온도      전압고조파평균
# 0.000000    0.000000  20.625  0.683594    42
#                       18.125  1.464844    40
#                               0.683594    36
#                               1.432292    31
#                       17.500  1.432292    30
#                                           ..
# 59.739582   0.946374  19.375  4.980469     1
# 59.729168   0.955298  20.625  1.464844     1
#             0.947429  19.375  3.255208     1
#             0.947406  20.000  4.003906     1
# 144.229172  0.388017  28.125  4.622396     1
# Length: 36135, dtype: int64

# %% [markdown]
#  # features 평균값과 평균이 아닌값 어떻게 처리할 것인가??

# %% [markdown]
# 다변량 역률평균값 예측해보기

# %%
import pandas as pd

comp_1_one=pd.read_csv(r'C:\Users\user\Desktop\산공 빅데이터 경진대회\comp1_concat.csv')

TRAIN_SPLIT = 43135

# %%
comp_1_one=comp_1_one.set_index('TIME')
comp_1_one.drop('Unnamed: 0',axis=1,inplace=True)

# %%
comp_1_one

# %%
comp_1_one.plot(subplots=False)
plt.show()

# %%
comp_1_one = comp_1_one.values
comp_1_one_mean = comp_1_one[:TRAIN_SPLIT].mean(axis=0)
comp_1_one_std = comp_1_one[:TRAIN_SPLIT].std(axis=0)
comp_1_one = (comp_1_one - comp_1_one_mean) / comp_1_one_std  # Standardization

print(comp_1_one)
# Out:
# [[ 2.01450145 -0.79358048  0.30365146 -0.6373581 ]
#  [ 0.45295128 -0.79571793  0.30365146 -0.6373581 ]
#  [ 2.03174464 -0.79358343  0.30365146 -0.63867235]
#  ...
#  [-0.83186844 -0.83186844 -0.12532272 -0.70569956]
#  [-0.83186844 -0.83186844 -0.1505565  -0.70175679]
#  [-0.83186844 -0.83186844 -0.12532272 -0.70175679]]

# %% [markdown]
# # 한스텝 예측

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i:i + target_size])
    return np.array(data), np.array(labels)

# %%
past_history = 720
future_target = 72
STEP = 6 

x_train_single, y_train_single = multivariate_data(comp_1_one, comp_1_one[:, 3], 0, TRAIN_SPLIT, past_history,
                                                   future_target, STEP, single_step=True)
x_val_single, y_val_single = multivariate_data(comp_1_one, comp_1_one[:, 3], TRAIN_SPLIT, None, past_history,
                                               future_target, STEP, single_step=True)

print('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (120, 4)

# %%
BUFFER_SIZE = 100
BATCH_SIZE = 500
EPOCHS = 100
EVALUATION_INTERVAL = 10

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dropout(0.3)) ##과대적합 방지##
single_step_model.add(tf.keras.layers.Dense(1))
single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mean_squared_error',metrics=['mae'])

for x, y in val_data_single.take(1):
    print(single_step_model.predict(x).shape)
# Out:
# (500, 1)

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 7s 530ms/step - loss: 0.1405 - mae: 0.3042 - val_loss: 0.0692 - val_mae: 0.2501
# Epoch 2/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0510 - mae: 0.1789 - val_loss: 0.0153 - val_mae: 0.0935
# Epoch 3/100
# 10/10 [==============================] - 4s 478ms/step - loss: 0.0321 - mae: 0.1439 - val_loss: 0.0171 - val_mae: 0.0992
# Epoch 4/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0269 - mae: 0.1315 - val_loss: 0.0190 - val_mae: 0.1058
# Epoch 5/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0277 - mae: 0.1332 - val_loss: 0.0028 - val_mae: 0.0425
# Epoch 6/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0214 - mae: 0.1165 - val_loss: 0.0038 - val_mae: 0.0521
# Epoch 7/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0225 - mae: 0.1200 - val_loss: 0.0041 - val_mae: 0.0552
# Epoch 8/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0171 - mae: 0.1044 - val_loss: 0.0019 - val_mae: 0.0354
# Epoch 9/100
# 10/10 [==============================] - 5s 564ms/step - loss: 0.0166 - mae: 0.1030 - val_loss: 0.0032 - val_mae: 0.0464
# Epoch 10/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0145 - mae: 0.0956 - val_loss: 0.0023 - val_mae: 0.0399
# Epoch 11/100
# 10/10 [==============================] - 5s 508ms/step - loss: 0.0167 - mae: 0.1024 - val_loss: 0.0037 - val_mae: 0.0492
# Epoch 12/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0132 - mae: 0.0908 - val_loss: 0.0050 - val_mae: 0.0603
# Epoch 13/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0145 - mae: 0.0958 - val_loss: 0.0028 - val_mae: 0.0456
# Epoch 14/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0119 - mae: 0.0870 - val_loss: 0.0049 - val_mae: 0.0582
# Epoch 15/100
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0115 - mae: 0.0857 - val_loss: 0.0012 - val_mae: 0.0271
# Epoch 16/100
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0105 - mae: 0.0812 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 17/100
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0118 - mae: 0.0855 - val_loss: 0.0018 - val_mae: 0.0348
# Epoch 18/100
# 10/10 [==============================] - 5s 495ms/step - loss: 0.0102 - mae: 0.0812 - val_loss: 0.0014 - val_mae: 0.0291
# Epoch 19/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0123 - mae: 0.0882 - val_loss: 0.0027 - val_mae: 0.0413
# Epoch 20/100
# 10/10 [==============================] - 5s 542ms/step - loss: 0.0095 - mae: 0.0774 - val_loss: 0.0013 - val_mae: 0.0277
# Epoch 21/100
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0098 - mae: 0.0791 - val_loss: 0.0023 - val_mae: 0.0387
# Epoch 22/100
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0096 - mae: 0.0774 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 23/100
# 10/10 [==============================] - 5s 539ms/step - loss: 0.0085 - mae: 0.0740 - val_loss: 0.0022 - val_mae: 0.0371
# Epoch 24/100
# 10/10 [==============================] - 5s 558ms/step - loss: 0.0088 - mae: 0.0747 - val_loss: 0.0014 - val_mae: 0.0303
# Epoch 25/100
# 10/10 [==============================] - 5s 519ms/step - loss: 0.0107 - mae: 0.0823 - val_loss: 0.0043 - val_mae: 0.0540
# Epoch 26/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0085 - mae: 0.0736 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 27/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0084 - mae: 0.0730 - val_loss: 0.0026 - val_mae: 0.0404
# Epoch 28/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0096 - mae: 0.0766 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 29/100
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0073 - mae: 0.0677 - val_loss: 0.0020 - val_mae: 0.0369
# Epoch 30/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0081 - mae: 0.0720 - val_loss: 0.0031 - val_mae: 0.0448
# Epoch 31/100
# 10/10 [==============================] - 5s 502ms/step - loss: 0.0095 - mae: 0.0773 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 32/100
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0083 - mae: 0.0727 - val_loss: 0.0040 - val_mae: 0.0530
# Epoch 33/100
# 10/10 [==============================] - 5s 530ms/step - loss: 0.0079 - mae: 0.0706 - val_loss: 0.0012 - val_mae: 0.0270
# Epoch 34/100
# 10/10 [==============================] - 5s 557ms/step - loss: 0.0087 - mae: 0.0729 - val_loss: 0.0019 - val_mae: 0.0347
# Epoch 35/100
# 10/10 [==============================] - 5s 530ms/step - loss: 0.0074 - mae: 0.0684 - val_loss: 0.0038 - val_mae: 0.0533
# Epoch 36/100
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0080 - mae: 0.0717 - val_loss: 0.0019 - val_mae: 0.0351
# Epoch 37/100
# 10/10 [==============================] - 5s 584ms/step - loss: 0.0093 - mae: 0.0768 - val_loss: 0.0023 - val_mae: 0.0378
# Epoch 38/100
# 10/10 [==============================] - 5s 529ms/step - loss: 0.0078 - mae: 0.0706 - val_loss: 0.0013 - val_mae: 0.0283
# Epoch 39/100
# 10/10 [==============================] - 5s 513ms/step - loss: 0.0065 - mae: 0.0646 - val_loss: 0.0025 - val_mae: 0.0401
# Epoch 40/100
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0084 - mae: 0.0724 - val_loss: 0.0027 - val_mae: 0.0433
# Epoch 41/100
# 10/10 [==============================] - 5s 502ms/step - loss: 0.0070 - mae: 0.0675 - val_loss: 0.0019 - val_mae: 0.0350
# Epoch 42/100
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0074 - mae: 0.0688 - val_loss: 0.0012 - val_mae: 0.0274
# Epoch 43/100
# 10/10 [==============================] - 5s 504ms/step - loss: 0.0081 - mae: 0.0719 - val_loss: 0.0018 - val_mae: 0.0341
# Epoch 44/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0079 - mae: 0.0714 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 45/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0059 - mae: 0.0619 - val_loss: 0.0018 - val_mae: 0.0335
# Epoch 46/100
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0081 - mae: 0.0710 - val_loss: 0.0020 - val_mae: 0.0364
# Epoch 47/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0065 - mae: 0.0649 - val_loss: 0.0022 - val_mae: 0.0384
# Epoch 48/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0077 - mae: 0.0703 - val_loss: 0.0015 - val_mae: 0.0296
# Epoch 49/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0076 - mae: 0.0692 - val_loss: 0.0014 - val_mae: 0.0301
# Epoch 50/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0072 - mae: 0.0683 - val_loss: 0.0022 - val_mae: 0.0369
# Epoch 51/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0058 - mae: 0.0605 - val_loss: 0.0012 - val_mae: 0.0270
# Epoch 52/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0073 - mae: 0.0672 - val_loss: 0.0024 - val_mae: 0.0410
# Epoch 53/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0062 - mae: 0.0623 - val_loss: 0.0018 - val_mae: 0.0341
# Epoch 54/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0080 - mae: 0.0712 - val_loss: 0.0024 - val_mae: 0.0389
# Epoch 55/100
# 10/10 [==============================] - 5s 540ms/step - loss: 0.0069 - mae: 0.0666 - val_loss: 0.0021 - val_mae: 0.0368
# Epoch 56/100
# 10/10 [==============================] - 5s 559ms/step - loss: 0.0071 - mae: 0.0673 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 57/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0054 - mae: 0.0590 - val_loss: 0.0020 - val_mae: 0.0352
# Epoch 58/100
# 10/10 [==============================] - 5s 539ms/step - loss: 0.0072 - mae: 0.0675 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 59/100
# 10/10 [==============================] - 5s 514ms/step - loss: 0.0061 - mae: 0.0626 - val_loss: 0.0017 - val_mae: 0.0340
# Epoch 60/100
# 10/10 [==============================] - 5s 516ms/step - loss: 0.0075 - mae: 0.0690 - val_loss: 0.0022 - val_mae: 0.0377
# Epoch 61/100
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0064 - mae: 0.0640 - val_loss: 0.0019 - val_mae: 0.0341
# Epoch 62/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0068 - mae: 0.0661 - val_loss: 0.0014 - val_mae: 0.0294
# Epoch 63/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0051 - mae: 0.0573 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 64/100
# 10/10 [==============================] - 5s 516ms/step - loss: 0.0071 - mae: 0.0665 - val_loss: 0.0016 - val_mae: 0.0326
# Epoch 65/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0062 - mae: 0.0629 - val_loss: 0.0025 - val_mae: 0.0417
# Epoch 66/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0071 - mae: 0.0668 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 67/100
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0061 - mae: 0.0620 - val_loss: 0.0014 - val_mae: 0.0304
# Epoch 68/100
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0060 - mae: 0.0618 - val_loss: 0.0024 - val_mae: 0.0389
# Epoch 69/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0051 - mae: 0.0570 - val_loss: 0.0013 - val_mae: 0.0290
# Epoch 70/100
# 10/10 [==============================] - 5s 499ms/step - loss: 0.0068 - mae: 0.0654 - val_loss: 0.0028 - val_mae: 0.0443
# Epoch 71/100
# 10/10 [==============================] - 5s 495ms/step - loss: 0.0058 - mae: 0.0613 - val_loss: 0.0022 - val_mae: 0.0383
# Epoch 72/100
# 10/10 [==============================] - 5s 495ms/step - loss: 0.0069 - mae: 0.0657 - val_loss: 0.0025 - val_mae: 0.0432
# Epoch 73/100
# 10/10 [==============================] - 5s 515ms/step - loss: 0.0054 - mae: 0.0591 - val_loss: 0.0027 - val_mae: 0.0419
# Epoch 74/100
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0057 - mae: 0.0606 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 75/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0052 - mae: 0.0574 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 76/100
# 10/10 [==============================] - 5s 559ms/step - loss: 0.0061 - mae: 0.0617 - val_loss: 0.0018 - val_mae: 0.0338
# Epoch 77/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0056 - mae: 0.0594 - val_loss: 0.0016 - val_mae: 0.0327
# Epoch 78/100
# 10/10 [==============================] - 5s 534ms/step - loss: 0.0066 - mae: 0.0650 - val_loss: 0.0014 - val_mae: 0.0304
# Epoch 79/100
# 10/10 [==============================] - 5s 579ms/step - loss: 0.0052 - mae: 0.0573 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 80/100
# 10/10 [==============================] - 5s 545ms/step - loss: 0.0056 - mae: 0.0599 - val_loss: 0.0016 - val_mae: 0.0321
# Epoch 81/100
# 10/10 [==============================] - 5s 559ms/step - loss: 0.0056 - mae: 0.0593 - val_loss: 0.0012 - val_mae: 0.0283
# Epoch 82/100
# 10/10 [==============================] - 5s 512ms/step - loss: 0.0051 - mae: 0.0571 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 83/100
# 10/10 [==============================] - 5s 560ms/step - loss: 0.0052 - mae: 0.0573 - val_loss: 0.0018 - val_mae: 0.0334
# Epoch 84/100
# 10/10 [==============================] - 5s 552ms/step - loss: 0.0065 - mae: 0.0656 - val_loss: 0.0026 - val_mae: 0.0412
# Epoch 85/100
# 10/10 [==============================] - 5s 542ms/step - loss: 0.0052 - mae: 0.0579 - val_loss: 0.0014 - val_mae: 0.0303
# Epoch 86/100
# 10/10 [==============================] - 5s 531ms/step - loss: 0.0052 - mae: 0.0571 - val_loss: 0.0017 - val_mae: 0.0325
# Epoch 87/100
# 10/10 [==============================] - 5s 549ms/step - loss: 0.0061 - mae: 0.0613 - val_loss: 0.0019 - val_mae: 0.0344
# Epoch 88/100
# 10/10 [==============================] - 5s 592ms/step - loss: 0.0046 - mae: 0.0546 - val_loss: 0.0018 - val_mae: 0.0349
# Epoch 89/100
# 10/10 [==============================] - 5s 547ms/step - loss: 0.0051 - mae: 0.0567 - val_loss: 0.0022 - val_mae: 0.0389
# Epoch 90/100
# 10/10 [==============================] - 5s 528ms/step - loss: 0.0063 - mae: 0.0632 - val_loss: 0.0013 - val_mae: 0.0290
# Epoch 91/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0048 - mae: 0.0553 - val_loss: 0.0025 - val_mae: 0.0406
# Epoch 92/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0050 - mae: 0.0562 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 93/100
# 10/10 [==============================] - 5s 493ms/step - loss: 0.0053 - mae: 0.0574 - val_loss: 0.0021 - val_mae: 0.0362
# Epoch 94/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0050 - mae: 0.0568 - val_loss: 0.0031 - val_mae: 0.0467
# Epoch 95/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0048 - mae: 0.0555 - val_loss: 0.0020 - val_mae: 0.0351
# Epoch 96/100
# 10/10 [==============================] - 5s 489ms/step - loss: 0.0057 - mae: 0.0605 - val_loss: 0.0019 - val_mae: 0.0352
# Epoch 97/100
# 10/10 [==============================] - 5s 502ms/step - loss: 0.0051 - mae: 0.0572 - val_loss: 0.0015 - val_mae: 0.0307
# Epoch 98/100
# 10/10 [==============================] - 5s 494ms/step - loss: 0.0042 - mae: 0.0522 - val_loss: 0.0016 - val_mae: 0.0321
# Epoch 99/100
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0052 - mae: 0.0572 - val_loss: 0.0030 - val_mae: 0.0460
# Epoch 100/100
# 10/10 [==============================] - 5s 542ms/step - loss: 0.0046 - mae: 0.0539 - val_loss: 0.0022 - val_mae: 0.0369

# %%
scores=single_step_model.evaluate(x_val_single, y_val_single,batch_size=1000)
# Out:
# 13/13 [==============================] - 2s 114ms/step - loss: 0.0022 - mae: 0.0369

# %%
scores
# Out:
# [0.0021555267740041018, 0.03687285631895065]

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

plot_train_history(single_step_history,
                   'Single Step Training and Validation Loss')

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.axis('auto')
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
for x, y in val_data_single.take(10):
    plot = show_plot([x[0][:,3].numpy(), y[0].numpy(), 
                      single_step_model.predict(x)[0]], 12,
                     'Single Step Prediction') 
    plot.show()

# %% [markdown]
# Multi Step

# %%
TRAIN_SPLIT = 30000

# %%
past_history = 720 # 60분 * 24시간 * 2일
future_target = 72 # 60분*3 -> 1시간 기준으로 3시간후
STEP = 6 #1분 -> 1시간이니까

x_train_multi, y_train_multi = multivariate_data(comp_1_one, comp_1_one[:, 3], 0, TRAIN_SPLIT, past_history,
                                                   future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(comp_1_one, comp_1_one[:, 3], TRAIN_SPLIT, None, past_history,
                                               future_target, STEP)

print('Single window of past history : {}'.format(x_train_multi[0].shape))
print('\n Target 역률평균 to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (120, 4)
#
#  Target 역률평균 to predict : (72,)

# %%
BUFFER_SIZE = 1000
BATCH_SIZE = 1000 #전체 데이터를 몇 개의 그룹으로 나눠서 학습할때 나누는 그 크기 (최대한 키우기)
EPOCHS = 100 #학습 반복 횟수 (Validation set에서 epoch 늘릴수록 에러 감소하다가 어느 지점에서 다시 증가 -> 최소)
EVALUATION_INTERVAL = 10

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32, return_sequences=True,input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(72))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mean_squared_error',metrics=['mae'])

# %%
for x, y in val_data_multi.take(1):
    print(multi_step_model.predict(x).shape)
# Out:
# (1000, 72)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_multi,
                                            validation_steps=50)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.4645 - mae: 0.6690 - val_loss: 0.4216 - val_mae: 0.6218
# Epoch 2/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3671 - mae: 0.5537 - val_loss: 0.3493 - val_mae: 0.5344
# Epoch 3/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.3280 - mae: 0.5007 - val_loss: 0.2733 - val_mae: 0.4428
# Epoch 4/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.2437 - mae: 0.4076 - val_loss: 0.2116 - val_mae: 0.3748
# Epoch 5/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.1792 - mae: 0.3353 - val_loss: 0.1603 - val_mae: 0.3079
# Epoch 6/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.1478 - mae: 0.2942 - val_loss: 0.1151 - val_mae: 0.2480
# Epoch 7/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0988 - mae: 0.2320 - val_loss: 0.0802 - val_mae: 0.1983
# Epoch 8/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0654 - mae: 0.1860 - val_loss: 0.0526 - val_mae: 0.1533
# Epoch 9/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0474 - mae: 0.1540 - val_loss: 0.0341 - val_mae: 0.1245
# Epoch 10/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0267 - mae: 0.1129 - val_loss: 0.0179 - val_mae: 0.0831
# Epoch 11/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0153 - mae: 0.0896 - val_loss: 0.0111 - val_mae: 0.0694
# Epoch 12/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0104 - mae: 0.0743 - val_loss: 0.0069 - val_mae: 0.0601
# Epoch 13/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0058 - mae: 0.0557 - val_loss: 0.0042 - val_mae: 0.0489
# Epoch 14/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0046 - mae: 0.0565 - val_loss: 0.0036 - val_mae: 0.0476
# Epoch 15/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0041 - mae: 0.0523 - val_loss: 0.0028 - val_mae: 0.0434
# Epoch 16/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0034 - mae: 0.0460 - val_loss: 0.0027 - val_mae: 0.0426
# Epoch 17/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0034 - mae: 0.0499 - val_loss: 0.0029 - val_mae: 0.0443
# Epoch 18/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0035 - mae: 0.0487 - val_loss: 0.0024 - val_mae: 0.0390
# Epoch 19/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0023 - val_mae: 0.0390
# Epoch 20/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0037 - mae: 0.0495 - val_loss: 0.0015 - val_mae: 0.0302
# Epoch 21/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0033 - mae: 0.0481 - val_loss: 0.0039 - val_mae: 0.0544
# Epoch 22/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0031 - mae: 0.0458 - val_loss: 0.0014 - val_mae: 0.0299
# Epoch 23/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0017 - mae: 0.0323 - val_loss: 0.0029 - val_mae: 0.0444
# Epoch 24/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0041 - mae: 0.0498 - val_loss: 0.0025 - val_mae: 0.0417
# Epoch 25/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0030 - mae: 0.0449 - val_loss: 0.0014 - val_mae: 0.0301
# Epoch 26/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0018 - mae: 0.0331 - val_loss: 0.0025 - val_mae: 0.0396
# Epoch 27/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0037 - mae: 0.0494 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 28/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0022 - mae: 0.0376 - val_loss: 0.0024 - val_mae: 0.0399
# Epoch 29/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0023 - mae: 0.0385 - val_loss: 0.0027 - val_mae: 0.0433
# Epoch 30/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0032 - mae: 0.0449 - val_loss: 0.0028 - val_mae: 0.0443
# Epoch 31/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0029 - mae: 0.0446 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 32/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0015 - mae: 0.0305 - val_loss: 0.0025 - val_mae: 0.0401
# Epoch 33/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0034 - mae: 0.0473 - val_loss: 0.0026 - val_mae: 0.0419
# Epoch 34/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0027 - mae: 0.0424 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 35/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0025 - val_mae: 0.0400
# Epoch 36/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0034 - mae: 0.0466 - val_loss: 0.0029 - val_mae: 0.0450
# Epoch 37/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0026 - mae: 0.0417 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 38/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0012 - mae: 0.0278 - val_loss: 0.0033 - val_mae: 0.0464
# Epoch 39/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0034 - mae: 0.0474 - val_loss: 0.0013 - val_mae: 0.0287
# Epoch 40/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0015 - mae: 0.0305 - val_loss: 0.0022 - val_mae: 0.0377
# Epoch 41/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0026 - mae: 0.0414 - val_loss: 0.0015 - val_mae: 0.0308
# Epoch 42/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0025 - mae: 0.0404 - val_loss: 0.0024 - val_mae: 0.0400
# Epoch 43/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.0027 - mae: 0.0424 - val_loss: 0.0013 - val_mae: 0.0296
# Epoch 44/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0013 - mae: 0.0285 - val_loss: 0.0028 - val_mae: 0.0433
# Epoch 45/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.0031 - mae: 0.0454 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 46/100
# 10/10 [==============================] - 34s 4s/step - loss: 0.0015 - mae: 0.0307 - val_loss: 0.0020 - val_mae: 0.0359
# Epoch 47/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0024 - mae: 0.0397 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 48/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0024 - mae: 0.0392 - val_loss: 0.0026 - val_mae: 0.0422
# Epoch 49/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0025 - mae: 0.0409 - val_loss: 0.0013 - val_mae: 0.0296
# Epoch 50/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0014 - mae: 0.0298 - val_loss: 0.0038 - val_mae: 0.0524
# Epoch 51/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0028 - mae: 0.0412 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 52/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0022 - mae: 0.0376 - val_loss: 0.0014 - val_mae: 0.0307
# Epoch 53/100
# 10/10 [==============================] - 36s 4s/step - loss: 0.0015 - mae: 0.0312 - val_loss: 0.0026 - val_mae: 0.0422
# Epoch 54/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0026 - mae: 0.0391 - val_loss: 0.0025 - val_mae: 0.0414
# Epoch 55/100
# 10/10 [==============================] - 34s 4s/step - loss: 0.0024 - mae: 0.0398 - val_loss: 0.0013 - val_mae: 0.0294
# Epoch 56/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0014 - mae: 0.0298 - val_loss: 0.0024 - val_mae: 0.0398
# Epoch 57/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0027 - mae: 0.0405 - val_loss: 0.0024 - val_mae: 0.0402
# Epoch 58/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0022 - mae: 0.0388 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 59/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0012 - mae: 0.0280 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 60/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0027 - mae: 0.0412 - val_loss: 0.0029 - val_mae: 0.0449
# Epoch 61/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.0022 - mae: 0.0384 - val_loss: 0.0014 - val_mae: 0.0302
# Epoch 62/100
# 10/10 [==============================] - 33s 3s/step - loss: 0.0012 - mae: 0.0270 - val_loss: 0.0033 - val_mae: 0.0488
# Epoch 63/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0027 - mae: 0.0409 - val_loss: 0.0013 - val_mae: 0.0289
# Epoch 64/100
# 10/10 [==============================] - 36s 4s/step - loss: 0.0015 - mae: 0.0306 - val_loss: 0.0014 - val_mae: 0.0302
# Epoch 65/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0021 - mae: 0.0376 - val_loss: 0.0014 - val_mae: 0.0297
# Epoch 66/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0020 - mae: 0.0353 - val_loss: 0.0026 - val_mae: 0.0422
# Epoch 67/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0022 - mae: 0.0389 - val_loss: 0.0013 - val_mae: 0.0292
# Epoch 68/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0016 - mae: 0.0323 - val_loss: 0.0036 - val_mae: 0.0514
# Epoch 69/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0020 - mae: 0.0355 - val_loss: 0.0016 - val_mae: 0.0321
# Epoch 70/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0020 - mae: 0.0356 - val_loss: 0.0016 - val_mae: 0.0328
# Epoch 71/100
# 10/10 [==============================] - 36s 4s/step - loss: 0.0017 - mae: 0.0330 - val_loss: 0.0031 - val_mae: 0.0465
# Epoch 72/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0015 - val_mae: 0.0313
# Epoch 73/100
# 10/10 [==============================] - 36s 4s/step - loss: 0.0017 - mae: 0.0326 - val_loss: 0.0022 - val_mae: 0.0384
# Epoch 74/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0019 - mae: 0.0352 - val_loss: 0.0019 - val_mae: 0.0353
# Epoch 75/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0021 - mae: 0.0368 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 76/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0014 - mae: 0.0297 - val_loss: 0.0024 - val_mae: 0.0393
# Epoch 77/100
# 10/10 [==============================] - 33s 3s/step - loss: 0.0020 - mae: 0.0363 - val_loss: 0.0019 - val_mae: 0.0347
# Epoch 78/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.0020 - mae: 0.0361 - val_loss: 0.0014 - val_mae: 0.0298
# Epoch 79/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.0015 - mae: 0.0311 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 80/100
# 10/10 [==============================] - 38s 4s/step - loss: 0.0018 - mae: 0.0336 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 81/100
# 10/10 [==============================] - 34s 4s/step - loss: 0.0021 - mae: 0.0365 - val_loss: 0.0013 - val_mae: 0.0288
# Epoch 82/100
# 10/10 [==============================] - 35s 4s/step - loss: 0.0016 - mae: 0.0316 - val_loss: 0.0017 - val_mae: 0.0330
# Epoch 83/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0018 - mae: 0.0344 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 84/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0019 - mae: 0.0351 - val_loss: 0.0013 - val_mae: 0.0292
# Epoch 85/100
# 10/10 [==============================] - 33s 4s/step - loss: 0.0014 - mae: 0.0294 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 86/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0019 - mae: 0.0349 - val_loss: 0.0019 - val_mae: 0.0355
# Epoch 87/100
# 10/10 [==============================] - 29s 3s/step - loss: 0.0019 - mae: 0.0354 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 88/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0016 - mae: 0.0313 - val_loss: 0.0020 - val_mae: 0.0364
# Epoch 89/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0017 - mae: 0.0331 - val_loss: 0.0024 - val_mae: 0.0402
# Epoch 90/100
# 10/10 [==============================] - 30s 3s/step - loss: 0.0018 - mae: 0.0342 - val_loss: 0.0013 - val_mae: 0.0293
# Epoch 91/100
# 10/10 [==============================] - 34s 4s/step - loss: 0.0016 - mae: 0.0310 - val_loss: 0.0017 - val_mae: 0.0337
# Epoch 92/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0017 - mae: 0.0338 - val_loss: 0.0019 - val_mae: 0.0353
# Epoch 93/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0018 - mae: 0.0339 - val_loss: 0.0015 - val_mae: 0.0315
# Epoch 94/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0015 - mae: 0.0312 - val_loss: 0.0019 - val_mae: 0.0349
# Epoch 95/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0016 - mae: 0.0327 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 96/100
# 10/10 [==============================] - 31s 3s/step - loss: 0.0017 - mae: 0.0327 - val_loss: 0.0015 - val_mae: 0.0309
# Epoch 97/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0018 - mae: 0.0340 - val_loss: 0.0014 - val_mae: 0.0300
# Epoch 98/100
# 10/10 [==============================] - 34s 4s/step - loss: 0.0015 - mae: 0.0314 - val_loss: 0.0025 - val_mae: 0.0415
# Epoch 99/100
# 10/10 [==============================] - 32s 3s/step - loss: 0.0017 - mae: 0.0329 - val_loss: 0.0016 - val_mae: 0.0325
# Epoch 100/100
# 10/10 [==============================] - 36s 4s/step - loss: 0.0016 - mae: 0.0316 - val_loss: 0.0018 - val_mae: 0.0343

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

plot_train_history(multi_step_history,
                   'Multi-Step Training and Validation Loss')

# %% [markdown]
# Multi Step 예측

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12,6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)
    
    plt.plot(num_in, np.array(history[:,3]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future),'b-',label='True Future')
    
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP,np.array(prediction),'r-',label='Predicted Future')
    
    plt.legend(loc='upper left')
    #plt.ylim([-0.81,-0.79])
    plt.xlim([-15,15])
    plt.ylim([-0.9,-0.5])
    plt.show()

# %%
def create_time_steps(length):
    return list(range(-length,0))

# %%
for x, y in val_data_multi.take(20):
    multi_step_plot(x[0],y[0],multi_step_model.predict(x)[0])

# %%
scores=multi_step_model.evaluate(x_val_multi, y_val_multi,batch_size=1000)
# Out:
# 13/13 [==============================] - 8s 411ms/step - loss: 0.0018 - mae: 0.0342

# %%
scores
# Out:
# [0.0017936553340405226, 0.03424730524420738]

# %%
정확도 계산, 파라미터 튜닝, + 역률 돌려보기 + 원인 분석!
