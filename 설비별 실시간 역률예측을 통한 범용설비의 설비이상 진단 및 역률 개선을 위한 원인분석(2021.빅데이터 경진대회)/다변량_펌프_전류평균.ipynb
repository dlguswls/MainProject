# %% [markdown]
# # 공기압축기_선박엔진

# %% [markdown]
# # 설비명별 데이터프레임 생성

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
import matplotlib.font_manager as fm 

font_fname = 'C:/Windows/Fonts/Malgun.ttf' #적용할 폰트
font_family = fm.FontProperties(fname=font_fname).get_name() #폰트 설정
plt.rcParams["font.family"] = font_family  #폰트 적용

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
os.chdir(r"C:\Users\user\Desktop\산공 빅데이터 경진대회")

# %%
raw_data = pd.read_csv("공기압축기_선박엔진.csv")

# %%
raw_data.head(20)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 SVC_NAME  DEVICE_ID  \
# 0      6338880             0               0      SOH       1338
# 1      6338881             1               1      SOH       1338
# 2      6338882             2               2      SOH       1338
# 3      6338883             3               3      SOH       1338
# 4      6338884             4               4      SOH       1338
# 5      6338885             5               5      SOH       1338
# 6      6338886             6               6      SOH       1338
# 7      6338887             7               7      SOH       1338
# 8      6338888             8               8      SOH       1338
# 9      6338889             9               9      SOH       1338
# 10     6338890            10              10      SOH       1338
# 11     6338891            11              11      SOH       1338
# 12     6338892            12              12      SOH       1338
# 13     6338893            13              13      SOH       1338
# 14     6338894            14              14      SOH       1338
# 15     6338895            15              15      SOH       1338
# 16     6338896            16              16      SOH       1338
# 17     6338897            17              17      SOH       1338
# 18     6338898            18              18      SOH       1338
# 19     6338899            19              19      SOH       1338
#
#     DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR LOCATION COMPANY_TYPE  ...  \
# 0              1       CO-295            1981   경북 고령군           제조  ...
# 1              1       CO-295            1981   경북 고령군           제조  ...
# 2              1       CO-295            1981   경북 고령군           제조  ...
# 3              1       CO-295            1981   경북 고령군           제조  ...
# 4              1       CO-295            1981   경북 고령군           제조  ...
# 5              1       CO-295            1981   경북 고령군           제조  ...
# 6              1       CO-295            1981   경북 고령군           제조  ...
# 7              1       CO-295            1981   경북 고령군           제조  ...
# 8              1       CO-295            1981   경북 고령군           제조  ...
# 9              1       CO-295            1981   경북 고령군           제조  ...
# 10             1       CO-295            1981   경북 고령군           제조  ...
# 11             1       CO-295            1981   경북 고령군           제조  ...
# 12             1       CO-295            1981   경북 고령군           제조  ...
# 13             1       CO-295            1981   경북 고령군           제조  ...
# 14             1       CO-295            1981   경북 고령군           제조  ...
# 15             1       CO-295            1981   경북 고령군           제조  ...
# 16             1       CO-295            1981   경북 고령군           제조  ...
# 17             1       CO-295            1981   경북 고령군           제조  ...
# 18             1       CO-295            1981   경북 고령군           제조  ...
# 19             1       CO-295            1981   경북 고령군           제조  ...
#
#    facility_vendor facility_year  facility_capacity facility_volt ITEM_NAME  \
# 0      artlascopco          2004                 86           380     누적전력량
# 1      artlascopco          2004                 86           380        온도
# 2      artlascopco          2004                 86           380     상전압평균
# 3      artlascopco          2004                 86           380    선간전압평균
# 4      artlascopco          2004                 86           380   전압고조파평균
# 5      artlascopco          2004                 86           380      전류평균
# 6      artlascopco          2004                 86           380   전류고조파평균
# 7      artlascopco          2004                 86           380      역률평균
# 8      artlascopco          2004                 86           380    무효전력평균
# 9      artlascopco          2004                 86           380       주파수
# 10     artlascopco          2004                 86           380    유효전력평균
# 11     artlascopco          2004                 86           380       주파수
# 12     artlascopco          2004                 86           380      전류평균
# 13     artlascopco          2004                 86           380     상전압평균
# 14     artlascopco          2004                 86           380        온도
# 15     artlascopco          2004                 86           380    무효전력평균
# 16     artlascopco          2004                 86           380   전류고조파평균
# 17     artlascopco          2004                 86           380    유효전력평균
# 18     artlascopco          2004                 86           380   전압고조파평균
# 19     artlascopco          2004                 86           380     누적전력량
#
#        ITEM_VALUE            TIMESTAMP 역률평균_LABEL  전류고조파평균_LABEL  \
# 0   270288.200000  2020-10-22 00:00:22         정상             정상
# 1       28.125000  2020-10-22 00:00:22         정상             정상
# 2      223.500000  2020-10-22 00:00:22         정상             정상
# 3      387.250000  2020-10-22 00:00:22         정상             정상
# 4        4.817708  2020-10-22 00:00:22         정상             정상
# 5       70.500000  2020-10-22 00:00:22         정상             정상
# 6        5.891927  2020-10-22 00:00:22         정상             정상
# 7        0.948331  2020-10-22 00:00:22         정상             정상
# 8    14954.000000  2020-10-22 00:00:22         정상             정상
# 9       59.872740  2020-10-22 00:00:22         정상             정상
# 10   44696.000000  2020-10-22 00:00:22         정상             정상
# 11      59.863403  2020-10-22 00:01:22         정상             정상
# 12      31.822916  2020-10-22 00:01:22         정상             정상
# 13     223.500000  2020-10-22 00:01:22         정상             정상
# 14      28.125000  2020-10-22 00:01:22         정상             정상
# 15    9604.500000  2020-10-22 00:01:22         정상             정상
# 16       6.510417  2020-10-22 00:01:22         정상             정상
# 17   19313.000000  2020-10-22 00:01:22         정상             정상
# 18       4.817708  2020-10-22 00:01:22         정상             정상
# 19  270840.156000  2020-10-22 00:01:22         정상             정상
#
#     전압고조파평균_LABEL
# 0              주의
# 1              주의
# 2              주의
# 3              주의
# 4              주의
# 5              주의
# 6              주의
# 7              주의
# 8              주의
# 9              주의
# 10             주의
# 11             주의
# 12             주의
# 13             주의
# 14             주의
# 15             주의
# 16             주의
# 17             주의
# 18             주의
# 19             주의
#
# [20 rows x 27 columns]

# %%
data_295 = raw_data[raw_data['COMPANY_NAME'] == 'CO-295']

# %%
data_295['facility_name'].value_counts()
# Out:
# 컴프레서_3    1663224
# 컴프레서_2    1663200
# 컴프레서_1    1509725
# Name: facility_name, dtype: int64

# %%
comp_1 = data_295[data_295['facility_name'] == '컴프레서_1']

# %%
comp_1
# Out:
#          Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 SVC_NAME  DEVICE_ID  \
# 0           6338880             0               0      SOH       1338
# 1           6338881             1               1      SOH       1338
# 2           6338882             2               2      SOH       1338
# 3           6338883             3               3      SOH       1338
# 4           6338884             4               4      SOH       1338
# ...             ...           ...             ...      ...        ...
# 1509720     7848600       1509720         1509720      SOH       1338
# 1509721     7848601       1509721         1509721      SOH       1338
# 1509722     7848602       1509722         1509722      SOH       1338
# 1509723     7848603       1509723         1509723      SOH       1338
# 1509724     7848604       1509724         1509724      SOH       1338
#
#          DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR LOCATION COMPANY_TYPE  ...  \
# 0                   1       CO-295            1981   경북 고령군           제조  ...
# 1                   1       CO-295            1981   경북 고령군           제조  ...
# 2                   1       CO-295            1981   경북 고령군           제조  ...
# 3                   1       CO-295            1981   경북 고령군           제조  ...
# 4                   1       CO-295            1981   경북 고령군           제조  ...
# ...               ...          ...             ...      ...          ...  ...
# 1509720             1       CO-295            1981   경북 고령군           제조  ...
# 1509721             1       CO-295            1981   경북 고령군           제조  ...
# 1509722             1       CO-295            1981   경북 고령군           제조  ...
# 1509723             1       CO-295            1981   경북 고령군           제조  ...
# 1509724             1       CO-295            1981   경북 고령군           제조  ...
#
#         facility_vendor facility_year  facility_capacity facility_volt  \
# 0           artlascopco          2004                 86           380
# 1           artlascopco          2004                 86           380
# 2           artlascopco          2004                 86           380
# 3           artlascopco          2004                 86           380
# 4           artlascopco          2004                 86           380
# ...                 ...           ...                ...           ...
# 1509720     artlascopco          2004                 86           380
# 1509721     artlascopco          2004                 86           380
# 1509722     artlascopco          2004                 86           380
# 1509723     artlascopco          2004                 86           380
# 1509724     artlascopco          2004                 86           380
#
#         ITEM_NAME     ITEM_VALUE            TIMESTAMP 역률평균_LABEL  \
# 0           누적전력량  270288.200000  2020-10-22 00:00:22         정상
# 1              온도      28.125000  2020-10-22 00:00:22         정상
# 2           상전압평균     223.500000  2020-10-22 00:00:22         정상
# 3          선간전압평균     387.250000  2020-10-22 00:00:22         정상
# 4         전압고조파평균       4.817708  2020-10-22 00:00:22         정상
# ...           ...            ...                  ...        ...
# 1509720    T상유효전력       0.000000  2020-11-22 23:59:35         경고
# 1509721    T상무효전력       0.000000  2020-11-22 23:59:35         경고
# 1509722      T상역률       0.000000  2020-11-22 23:59:35         경고
# 1509723   T상전압고조파       3.125000  2020-11-22 23:59:35         경고
# 1509724   T상전류고조파       0.000000  2020-11-22 23:59:35         경고
#
#          전류고조파평균_LABEL  전압고조파평균_LABEL
# 0                   정상             주의
# 1                   정상             주의
# 2                   정상             주의
# 3                   정상             주의
# 4                   정상             주의
# ...                ...            ...
# 1509720             정상             주의
# 1509721             정상             주의
# 1509722             정상             주의
# 1509723             정상             주의
# 1509724             정상             주의
#
# [1509725 rows x 27 columns]

# %%
col = ['전류평균', '온도', '선간전압평균', '상전압평균', '유효전력평균', '누적전력량', '역률평균', '주파수', '전압고조파평균', '무효전력평균']
comp_clear = comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,:-6]
for i in range(0,len(col)) : 
    values = list(comp_1[comp_1['ITEM_NAME']==col[i]]['ITEM_VALUE'])
    comp_clear[col[i]] = values

comp_clear['TIMESTAMP'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-4])   
comp_clear['역률평균_LABEL'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-3])
comp_clear['전압고조파평균_LABEL'] = list(comp_1[comp_1['ITEM_NAME']==col[0]].iloc[:,-1])

# %%
comp_clear = comp_clear.drop(columns=['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1'], axis=1)

# %%
comp_clear
# Out:
#         SVC_NAME  DEVICE_ID  DEVICE_BD_ID COMPANY_NAME  ESTABLISH_YEAR  \
# 5            SOH       1338             1       CO-295            1981
# 12           SOH       1338             1       CO-295            1981
# 22           SOH       1338             1       CO-295            1981
# 33           SOH       1338             1       CO-295            1981
# 52           SOH       1338             1       CO-295            1981
# ...          ...        ...           ...          ...             ...
# 1508239      SOH       1338             1       CO-295            1981
# 1508244      SOH       1338             1       CO-295            1981
# 1508257      SOH       1338             1       CO-295            1981
# 1508268      SOH       1338             1       CO-295            1981
# 1508278      SOH       1338             1       CO-295            1981
#
#         LOCATION COMPANY_TYPE COMPANY_CAT MAJOR_PRODUCT  CONTRACT_POWER  ...  \
# 5         경북 고령군           제조         열처리          선박엔진            7000  ...
# 12        경북 고령군           제조         열처리          선박엔진            7000  ...
# 22        경북 고령군           제조         열처리          선박엔진            7000  ...
# 33        경북 고령군           제조         열처리          선박엔진            7000  ...
# 52        경북 고령군           제조         열처리          선박엔진            7000  ...
# ...          ...          ...         ...           ...             ...  ...
# 1508239   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508244   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508257   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508268   경북 고령군           제조         열처리          선박엔진            7000  ...
# 1508278   경북 고령군           제조         열처리          선박엔진            7000  ...
#
#               상전압평균   유효전력평균         누적전력량      역률평균        주파수   전압고조파평균  \
# 5        223.500000  44696.0  2.702882e+05  0.948331  59.872740  4.817708
# 12       223.500000  19313.0  2.708402e+05  0.895390  59.863403  4.817708
# 22       223.333328  44907.0  2.714893e+05  0.948258  59.910122  4.785156
# 33       223.583328  46233.0  2.722598e+05  0.948171  59.872740  4.817708
# 52       223.750000  30076.0  2.729348e+05  0.937192  59.891440  4.817708
# ...             ...      ...           ...       ...        ...       ...
# 1508239  227.083328      0.0  1.549272e+07  0.000000  59.882076  3.190104
# 1508244  227.166672      0.0  1.549272e+07  0.000000  59.798140  3.190104
# 1508257  227.000000      0.0  1.549272e+07  0.000000  59.854070  3.125000
# 1508268  226.833328      0.0  1.549272e+07  0.000000  59.816770  3.222656
# 1508278  226.750000      0.0  1.549272e+07  0.000000  59.844740  3.222656
#
#           무효전력평균            TIMESTAMP  역률평균_LABEL  전압고조파평균_LABEL
# 5        14954.0  2020-10-22 00:00:22          정상             주의
# 12        9604.5  2020-10-22 00:01:22          정상             주의
# 22       15036.0  2020-10-22 00:02:22          정상             주의
# 33       15494.0  2020-10-22 00:03:22          정상             주의
# 52       11194.0  2020-10-22 00:04:22          정상             주의
# ...          ...                  ...         ...            ...
# 1508239      0.0  2020-11-22 23:55:35          경고             주의
# 1508244      0.0  2020-11-22 23:56:35          경고             주의
# 1508257      0.0  2020-11-22 23:57:35          경고             주의
# 1508268      0.0  2020-11-22 23:58:35          경고             주의
# 1508278      0.0  2020-11-22 23:59:35          경고             주의
#
# [43135 rows x 31 columns]

# %%
comp_clear.columns
# Out:
# Index(['SVC_NAME', 'DEVICE_ID', 'DEVICE_BD_ID', 'COMPANY_NAME',
#        'ESTABLISH_YEAR', 'LOCATION', 'COMPANY_TYPE', 'COMPANY_CAT',
#        'MAJOR_PRODUCT', 'CONTRACT_POWER', 'BILL_OPTION', 'KEPCO_INFO',
#        'facility_name', 'facility_type_name', 'facility_vendor',
#        'facility_year', 'facility_capacity', 'facility_volt', '전류평균', '온도',
#        '선간전압평균', '상전압평균', '유효전력평균', '누적전력량', '역률평균', '주파수', '전압고조파평균',
#        '무효전력평균', 'TIMESTAMP', '역률평균_LABEL', '전압고조파평균_LABEL'],
#       dtype='object')

# %%
comp_1_one = comp_clear[['전류평균','역률평균','온도','전압고조파평균','TIMESTAMP']]

# %%
comp_1_one
# Out:
#               전류평균      역률평균      온도   전압고조파평균            TIMESTAMP
# 5        70.500000  0.948331  28.125  4.817708  2020-10-22 00:00:22
# 12       31.822916  0.895390  28.125  4.817708  2020-10-22 00:01:22
# 22       70.927086  0.948258  28.125  4.785156  2020-10-22 00:02:22
# 33       72.843750  0.948171  27.500  4.817708  2020-10-22 00:03:22
# 52       47.104168  0.937192  28.750  4.817708  2020-10-22 00:04:22
# ...            ...       ...     ...       ...                  ...
# 1508239   0.000000  0.000000  16.875  3.190104  2020-11-22 23:55:35
# 1508244   0.000000  0.000000  16.875  3.190104  2020-11-22 23:56:35
# 1508257   0.000000  0.000000  17.500  3.125000  2020-11-22 23:57:35
# 1508268   0.000000  0.000000  16.875  3.222656  2020-11-22 23:58:35
# 1508278   0.000000  0.000000  17.500  3.222656  2020-11-22 23:59:35
#
# [43135 rows x 5 columns]

# %%
comp_1_one['TIME'] = pd.to_datetime(comp_1_one['TIMESTAMP'])
comp_1_one.drop('TIMESTAMP', axis = 1, inplace=True)
comp_1_one.set_index('TIME', inplace=True)

# %%
comp_1_one
# Out:
#                           전류평균      역률평균      온도   전압고조파평균
# TIME
# 2020-10-22 00:00:22  70.500000  0.948331  28.125  4.817708
# 2020-10-22 00:01:22  31.822916  0.895390  28.125  4.817708
# 2020-10-22 00:02:22  70.927086  0.948258  28.125  4.785156
# 2020-10-22 00:03:22  72.843750  0.948171  27.500  4.817708
# 2020-10-22 00:04:22  47.104168  0.937192  28.750  4.817708
# ...                        ...       ...     ...       ...
# 2020-11-22 23:55:35   0.000000  0.000000  16.875  3.190104
# 2020-11-22 23:56:35   0.000000  0.000000  16.875  3.190104
# 2020-11-22 23:57:35   0.000000  0.000000  17.500  3.125000
# 2020-11-22 23:58:35   0.000000  0.000000  16.875  3.222656
# 2020-11-22 23:59:35   0.000000  0.000000  17.500  3.222656
#
# [43135 rows x 4 columns]

# %%
comp_1_one['2020-10-22'].plot()
# Out:
# <AxesSubplot:xlabel='TIME'>

# %%
features = comp_1_one[['전류평균','역률평균','온도','전압고조파평균']]

# %%
features.plot(subplots=True)
plt.show()

# %%
comp_1_one.value_counts()
# Out:
# 전류평균        역률평균      온도      전압고조파평균
# 0.000000    0.000000  20.625  0.683594    42
#                       18.125  1.464844    40
#                               0.683594    36
#                               1.432292    31
#                       17.500  1.432292    30
#                                           ..
# 59.739582   0.946374  19.375  4.980469     1
# 59.729168   0.955298  20.625  1.464844     1
#             0.947429  19.375  3.255208     1
#             0.947406  20.000  4.003906     1
# 144.229172  0.388017  28.125  4.622396     1
# Length: 36135, dtype: int64

# %% [markdown]
#  # features 평균값과 평균이 아닌값 어떻게 처리할 것인가??

# %% [markdown]
# 다변량 역률평균값 예측해보기

# %% [markdown]
# features 표준화

# %%
TRAIN_SPLIT = 30000 #43000

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std
print(dataset)
# Out:
# [[ 0.66927044  0.41919719  0.90211106  1.56573178]
#  [-0.86009332  0.25790493  0.90211106  1.56573178]
#  [ 0.68615821  0.41897479  0.90211106  1.53434877]
#  ...
#  [-2.11843054 -2.47002774 -2.01336463 -0.06618862]
#  [-2.11843054 -2.47002774 -2.1848632   0.02796041]
#  [-2.11843054 -2.47002774 -2.01336463  0.02796041]]

# %%
features.plot(subplots=False)
plt.show()

# %%
comp_1_one = comp_1_one.values
comp_1_one_mean = comp_1_one[:TRAIN_SPLIT].mean()
comp_1_one_std = comp_1_one[:TRAIN_SPLIT].std()
comp_1_one = (comp_1_one - comp_1_one_mean) / comp_1_one_std  # Standardization

print(comp_1_one)
# Out:
# [[ 2.01450145 -0.79358048  0.30365146 -0.6373581 ]
#  [ 0.45295128 -0.79571793  0.30365146 -0.6373581 ]
#  [ 2.03174464 -0.79358343  0.30365146 -0.63867235]
#  ...
#  [-0.83186844 -0.83186844 -0.12532272 -0.70569956]
#  [-0.83186844 -0.83186844 -0.1505565  -0.70175679]
#  [-0.83186844 -0.83186844 -0.12532272 -0.70175679]]

# %% [markdown]
# # 한스텝 예측

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i - history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i + target_size])
        else:
            labels.append(target[i:i + target_size])
    return np.array(data), np.array(labels)

# %%
past_history = 720
future_target = 72
STEP = 6 

x_train_single, y_train_single = multivariate_data(comp_1_one, comp_1_one[:, 3], 0, TRAIN_SPLIT, past_history,
                                                   future_target, STEP, single_step=True)
x_val_single, y_val_single = multivariate_data(comp_1_one, comp_1_one[:, 3], TRAIN_SPLIT, None, past_history,
                                               future_target, STEP, single_step=True)

print('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (120, 1)

# %%
BUFFER_SIZE = 100
BATCH_SIZE = 500
EPOCHS = 100
EVALUATION_INTERVAL = 10

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dropout(0.3)) ##과대적합 방지##
single_step_model.add(tf.keras.layers.Dense(1))
single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

for x, y in val_data_single.take(1):
    print(single_step_model.predict(x).shape)
# Out:
# (500, 1)

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)

# %%
scores=single_step_model.evaluate(x_val_single, y_val_single,batch_size=1000)

# %%
scores

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

plot_train_history(single_step_history,
                   'Single Step Training and Validation Loss')
# Out:
# Epoch 1/100
# 10/10 [==============================] - 6s 522ms/step - loss: 0.3369 - val_loss: 0.0384
# Epoch 2/100
# 10/10 [==============================] - 4s 476ms/step - loss: 0.0373 - val_loss: 0.0340
# Epoch 3/100
# 10/10 [==============================] - 5s 493ms/step - loss: 0.0328 - val_loss: 0.0273
# Epoch 4/100
# 10/10 [==============================] - 4s 472ms/step - loss: 0.0308 - val_loss: 0.0226
# Epoch 5/100
# 10/10 [==============================] - 5s 487ms/step - loss: 0.0262 - val_loss: 0.0284
# Epoch 6/100
# 10/10 [==============================] - 5s 495ms/step - loss: 0.0325 - val_loss: 0.0202
# Epoch 7/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0303 - val_loss: 0.0270
# Epoch 8/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0308 - val_loss: 0.0412
# Epoch 9/100
# 10/10 [==============================] - 4s 484ms/step - loss: 0.0286 - val_loss: 0.0307
# Epoch 10/100
# 10/10 [==============================] - 5s 527ms/step - loss: 0.0250 - val_loss: 0.0348
# Epoch 11/100
# 10/10 [==============================] - 5s 506ms/step - loss: 0.0309 - val_loss: 0.0206
# Epoch 12/100
# 10/10 [==============================] - 4s 483ms/step - loss: 0.0282 - val_loss: 0.0403
# Epoch 13/100
# 10/10 [==============================] - 4s 466ms/step - loss: 0.0290 - val_loss: 0.0422
# Epoch 14/100
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0282 - val_loss: 0.0228
# Epoch 15/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0252 - val_loss: 0.0449
# Epoch 16/100
# 10/10 [==============================] - 4s 479ms/step - loss: 0.0243 - val_loss: 0.0350
# Epoch 17/100
# 10/10 [==============================] - 4s 477ms/step - loss: 0.0284 - val_loss: 0.0378
# Epoch 18/100
# 10/10 [==============================] - 4s 477ms/step - loss: 0.0290 - val_loss: 0.0292
# Epoch 19/100
# 10/10 [==============================] - 5s 490ms/step - loss: 0.0272 - val_loss: 0.0376
# Epoch 20/100
# 10/10 [==============================] - 5s 496ms/step - loss: 0.0240 - val_loss: 0.0316
# Epoch 21/100
# 10/10 [==============================] - 5s 486ms/step - loss: 0.0257 - val_loss: 0.0352
# Epoch 22/100
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0262 - val_loss: 0.0268
# Epoch 23/100
# 10/10 [==============================] - 5s 501ms/step - loss: 0.0255 - val_loss: 0.0247
# Epoch 24/100
# 10/10 [==============================] - 4s 463ms/step - loss: 0.0263 - val_loss: 0.0289
# Epoch 25/100
# 10/10 [==============================] - 4s 467ms/step - loss: 0.0281 - val_loss: 0.0215
# Epoch 26/100
# 10/10 [==============================] - 4s 463ms/step - loss: 0.0242 - val_loss: 0.0323
# Epoch 27/100
# 10/10 [==============================] - 4s 463ms/step - loss: 0.0260 - val_loss: 0.0254
# Epoch 28/100
# 10/10 [==============================] - 4s 463ms/step - loss: 0.0237 - val_loss: 0.0263
# Epoch 29/100
# 10/10 [==============================] - 4s 464ms/step - loss: 0.0269 - val_loss: 0.0225
# Epoch 30/100
# 10/10 [==============================] - 4s 469ms/step - loss: 0.0251 - val_loss: 0.0215
# Epoch 31/100
# 10/10 [==============================] - 4s 464ms/step - loss: 0.0265 - val_loss: 0.0237
# Epoch 32/100
# 10/10 [==============================] - 4s 472ms/step - loss: 0.0235 - val_loss: 0.0324
# Epoch 33/100
# 10/10 [==============================] - 4s 466ms/step - loss: 0.0248 - val_loss: 0.0211
# Epoch 34/100
# 10/10 [==============================] - 4s 467ms/step - loss: 0.0237 - val_loss: 0.0221
# Epoch 35/100
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0265 - val_loss: 0.0426
# Epoch 36/100
# 10/10 [==============================] - 5s 558ms/step - loss: 0.0255 - val_loss: 0.0323
# Epoch 37/100
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0272 - val_loss: 0.0322
# Epoch 38/100
# 10/10 [==============================] - 5s 567ms/step - loss: 0.0253 - val_loss: 0.0228
# Epoch 39/100
# 10/10 [==============================] - 5s 497ms/step - loss: 0.0204 - val_loss: 0.0296
# Epoch 40/100
# 10/10 [==============================] - 5s 522ms/step - loss: 0.0243 - val_loss: 0.0380
# Epoch 41/100
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0269 - val_loss: 0.0212
# Epoch 42/100
# 10/10 [==============================] - 4s 468ms/step - loss: 0.0247 - val_loss: 0.0228
# Epoch 43/100
# 10/10 [==============================] - 4s 472ms/step - loss: 0.0262 - val_loss: 0.0210
# Epoch 44/100
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0246 - val_loss: 0.0323
# Epoch 45/100
# 10/10 [==============================] - 5s 492ms/step - loss: 0.0216 - val_loss: 0.0211
# Epoch 46/100
# 10/10 [==============================] - 4s 481ms/step - loss: 0.0255 - val_loss: 0.0224
# Epoch 47/100
# 10/10 [==============================] - 4s 468ms/step - loss: 0.0244 - val_loss: 0.0213
# Epoch 48/100
# 10/10 [==============================] - 4s 472ms/step - loss: 0.0253 - val_loss: 0.0232
# Epoch 49/100
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0241 - val_loss: 0.0226
# Epoch 50/100
# 10/10 [==============================] - 4s 476ms/step - loss: 0.0250 - val_loss: 0.0206
# Epoch 51/100
# 10/10 [==============================] - 5s 488ms/step - loss: 0.0192 - val_loss: 0.0228
# Epoch 52/100
# 10/10 [==============================] - 4s 460ms/step - loss: 0.0250 - val_loss: 0.0205
# Epoch 53/100
# 10/10 [==============================] - 4s 481ms/step - loss: 0.0243 - val_loss: 0.0211
# Epoch 54/100
# 10/10 [==============================] - 4s 470ms/step - loss: 0.0261 - val_loss: 0.0323
# Epoch 55/100
# 10/10 [==============================] - 4s 460ms/step - loss: 0.0234 - val_loss: 0.0298
# Epoch 56/100
# 10/10 [==============================] - 4s 462ms/step - loss: 0.0238 - val_loss: 0.0258
# Epoch 57/100
# 10/10 [==============================] - 4s 468ms/step - loss: 0.0203 - val_loss: 0.0229
# Epoch 58/100
# 10/10 [==============================] - 4s 468ms/step - loss: 0.0250 - val_loss: 0.0291
# Epoch 59/100
# 10/10 [==============================] - 4s 457ms/step - loss: 0.0244 - val_loss: 0.0227
# Epoch 60/100
# 10/10 [==============================] - 4s 468ms/step - loss: 0.0257 - val_loss: 0.0253
# Epoch 61/100
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0236 - val_loss: 0.0201
# Epoch 62/100
# 10/10 [==============================] - 5s 581ms/step - loss: 0.0227 - val_loss: 0.0291
# Epoch 63/100
# 10/10 [==============================] - 5s 568ms/step - loss: 0.0194 - val_loss: 0.0202
# Epoch 64/100
# 10/10 [==============================] - 5s 511ms/step - loss: 0.0259 - val_loss: 0.0239
# Epoch 65/100
# 10/10 [==============================] - 5s 520ms/step - loss: 0.0228 - val_loss: 0.0276
# Epoch 66/100
# 10/10 [==============================] - 5s 487ms/step - loss: 0.0254 - val_loss: 0.0206
# Epoch 67/100
# 10/10 [==============================] - 4s 477ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 68/100
# 10/10 [==============================] - 4s 482ms/step - loss: 0.0235 - val_loss: 0.0201
# Epoch 69/100
# 10/10 [==============================] - 5s 486ms/step - loss: 0.0180 - val_loss: 0.0208
# Epoch 70/100
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0258 - val_loss: 0.0209
# Epoch 71/100
# 10/10 [==============================] - 5s 507ms/step - loss: 0.0248 - val_loss: 0.0230
# Epoch 72/100
# 10/10 [==============================] - 5s 543ms/step - loss: 0.0236 - val_loss: 0.0257
# Epoch 73/100
# 10/10 [==============================] - 6s 597ms/step - loss: 0.0218 - val_loss: 0.0276
# Epoch 74/100
# 10/10 [==============================] - 6s 631ms/step - loss: 0.0206 - val_loss: 0.0291
# Epoch 75/100
# 10/10 [==============================] - 5s 590ms/step - loss: 0.0186 - val_loss: 0.0318
# Epoch 76/100
# 10/10 [==============================] - 7s 700ms/step - loss: 0.0251 - val_loss: 0.0271
# Epoch 77/100
# 10/10 [==============================] - 6s 633ms/step - loss: 0.0235 - val_loss: 0.0239
# Epoch 78/100
# 10/10 [==============================] - 5s 539ms/step - loss: 0.0245 - val_loss: 0.0236
# Epoch 79/100
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0202 - val_loss: 0.0229
# Epoch 80/100
# 10/10 [==============================] - 5s 503ms/step - loss: 0.0223 - val_loss: 0.0235
# Epoch 81/100
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0197 - val_loss: 0.0247
# Epoch 82/100
# 10/10 [==============================] - 5s 536ms/step - loss: 0.0214 - val_loss: 0.0265
# Epoch 83/100
# 10/10 [==============================] - 5s 524ms/step - loss: 0.0212 - val_loss: 0.0236
# Epoch 84/100
# 10/10 [==============================] - 5s 522ms/step - loss: 0.0236 - val_loss: 0.0205
# Epoch 85/100
# 10/10 [==============================] - 5s 541ms/step - loss: 0.0193 - val_loss: 0.0310
# Epoch 86/100
# 10/10 [==============================] - 5s 576ms/step - loss: 0.0201 - val_loss: 0.0220
# Epoch 87/100
# 10/10 [==============================] - 5s 523ms/step - loss: 0.0207 - val_loss: 0.0271
# Epoch 88/100
# 10/10 [==============================] - 5s 509ms/step - loss: 0.0210 - val_loss: 0.0234
# Epoch 89/100
# 10/10 [==============================] - 4s 482ms/step - loss: 0.0214 - val_loss: 0.0197
# Epoch 90/100
# 10/10 [==============================] - 5s 545ms/step - loss: 0.0222 - val_loss: 0.0195
# Epoch 91/100
# 10/10 [==============================] - 4s 466ms/step - loss: 0.0189 - val_loss: 0.0302
# Epoch 92/100
# 10/10 [==============================] - 4s 471ms/step - loss: 0.0203 - val_loss: 0.0260
# Epoch 93/100
# 10/10 [==============================] - 4s 478ms/step - loss: 0.0209 - val_loss: 0.0199
# Epoch 94/100
# 10/10 [==============================] - 4s 483ms/step - loss: 0.0198 - val_loss: 0.0282
# Epoch 95/100
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0210 - val_loss: 0.0222
# Epoch 96/100
# 10/10 [==============================] - 5s 492ms/step - loss: 0.0215 - val_loss: 0.0217
# Epoch 97/100
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0203 - val_loss: 0.0215
# Epoch 98/100
# 10/10 [==============================] - 4s 471ms/step - loss: 0.0194 - val_loss: 0.0247
# Epoch 99/100
# 10/10 [==============================] - 4s 466ms/step - loss: 0.0198 - val_loss: 0.0309
# Epoch 100/100
# 10/10 [==============================] - 4s 469ms/step - loss: 0.0195 - val_loss: 0.0195

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.axis('auto')
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
for x, y in val_data_single.take(10):
    plot = show_plot([x[0][:,3].numpy(), y[0].numpy(), 
                      single_step_model.predict(x)[0]], 12,
                     'Single Step Prediction') 
    plot.show()

# %% [markdown]
# Multi Step

# %%
TRAIN_SPLIT = 30000

# %%
past_history = 720 # 60분 * 24시간 * 2일
future_target = 72 # 60분*3 -> 1시간 기준으로 3시간후
STEP = 6 #1분 -> 1시간이니까

x_train_multi, y_train_multi = multivariate_data(comp_1_one, comp_1_one[:, 3], 0, TRAIN_SPLIT, past_history,
                                                   future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(comp_1_one, comp_1_one[:, 3], TRAIN_SPLIT, None, past_history,
                                               future_target, STEP)

print('Single window of past history : {}'.format(x_train_multi[0].shape))
print('\n Target 역률평균 to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (120, 1)
#
#  Target 역률평균 to predict : (72,)

# %%
BUFFER_SIZE = 1000
BATCH_SIZE = 1000 #전체 데이터를 몇 개의 그룹으로 나눠서 학습할때 나누는 그 크기 (최대한 키우기)
EPOCHS = 100 #학습 반복 횟수 (Validation set에서 epoch 늘릴수록 에러 감소하다가 어느 지점에서 다시 증가 -> 최소)
EVALUATION_INTERVAL = 10

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32, return_sequences=True,input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(72))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mean_squared_error',metrics=['mae'])

# %%
for x, y in val_data_multi.take(1):
    print(multi_step_model.predict(x).shape)
# Out:
# (1000, 72)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_multi,
                                            validation_steps=50)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.6452 - val_loss: 0.5127
# Epoch 2/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.4546 - val_loss: 0.4089
# Epoch 3/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.3812 - val_loss: 0.3291
# Epoch 4/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.2907 - val_loss: 0.2543
# Epoch 5/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.2214 - val_loss: 0.2046
# Epoch 6/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.1766 - val_loss: 0.1506
# Epoch 7/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.1295 - val_loss: 0.1364
# Epoch 8/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.1050 - val_loss: 0.1078
# Epoch 9/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0821 - val_loss: 0.0917
# Epoch 10/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0729 - val_loss: 0.0973
# Epoch 11/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0641 - val_loss: 0.0690
# Epoch 12/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0544 - val_loss: 0.0652
# Epoch 13/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0528 - val_loss: 0.0742
# Epoch 14/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0521 - val_loss: 0.0747
# Epoch 15/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0472 - val_loss: 0.0692
# Epoch 16/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0492 - val_loss: 0.0280
# Epoch 17/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0405 - val_loss: 0.0339
# Epoch 18/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0510 - val_loss: 0.0531
# Epoch 19/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0428 - val_loss: 0.0281
# Epoch 20/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0392 - val_loss: 0.0326
# Epoch 21/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0495 - val_loss: 0.0526
# Epoch 22/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0410 - val_loss: 0.0287
# Epoch 23/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0421 - val_loss: 0.0310
# Epoch 24/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0437 - val_loss: 0.0321
# Epoch 25/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0430 - val_loss: 0.0269
# Epoch 26/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0344 - val_loss: 0.0330
# Epoch 27/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0482 - val_loss: 0.0482
# Epoch 28/100
# 10/10 [==============================] - 17s 2s/step - loss: 0.0397 - val_loss: 0.0270
# Epoch 29/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0411 - val_loss: 0.0309
# Epoch 30/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0392 - val_loss: 0.0399
# Epoch 31/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0427 - val_loss: 0.0270
# Epoch 32/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0382 - val_loss: 0.0292
# Epoch 33/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0385 - val_loss: 0.0385
# Epoch 34/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0421 - val_loss: 0.0535
# Epoch 35/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0396 - val_loss: 0.0533
# Epoch 36/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0379 - val_loss: 0.0398
# Epoch 37/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0396 - val_loss: 0.0481
# Epoch 38/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.0390 - val_loss: 0.0526
# Epoch 39/100
# 10/10 [==============================] - 18s 2s/step - loss: 0.0371 - val_loss: 0.0413
# Epoch 40/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0402 - val_loss: 0.0499
# Epoch 41/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0384 - val_loss: 0.0527
# Epoch 42/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0368 - val_loss: 0.0399
# Epoch 43/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0391 - val_loss: 0.0493
# Epoch 44/100
# 10/10 [==============================] - 20s 2s/step - loss: 0.0383 - val_loss: 0.0501
# Epoch 45/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0364 - val_loss: 0.0378
# Epoch 46/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.0381 - val_loss: 0.0466
# Epoch 47/100
# 10/10 [==============================] - ETA: 0s - loss: 0.0382

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

plot_train_history(multi_step_history,
                   'Multi-Step Training and Validation Loss')

# %% [markdown]
# Multi Step 예측

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12,6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)
    
    plt.plot(num_in, np.array(history[:,3]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future),'b-',label='True Future')
    
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP,np.array(prediction),'r-',label='Predicted Future')
    
    plt.legend(loc='upper left')
    #plt.ylim([-0.81,-0.79])
    plt.xlim([-10,15])
    plt.show()

# %%
def create_time_steps(length):
    return list(range(-length,0))

# %%
for x, y in val_data_multi.take(20):
    multi_step_plot(x[0],y[0],multi_step_model.predict(x)[0])

# %%
정확도 계산, 파라미터 튜닝, + 역률 돌려보기 + 원인 분석!
