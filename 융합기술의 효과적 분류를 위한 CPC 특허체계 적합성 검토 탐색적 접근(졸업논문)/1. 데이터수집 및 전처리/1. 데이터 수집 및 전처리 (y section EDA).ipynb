# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Capstone/data/y_section_2020_2021.csv")

# %%
df = df.drop('patent_date',axis=1)

# %%
df
# Out:
#        cpc_section_id patent_date  patent_number
# 0                   A  2020-01-07       10524409
# 1                   Y  2020-01-07       10524409
# 2                   A  2020-01-07       10524425
# 3                   B  2020-01-07       10524425
# 4                   G  2020-01-07       10524425
# ...               ...         ...            ...
# 195077              H  2021-12-28       11212938
# 195078              Y  2021-12-28       11212938
# 195079              G  2021-12-28       11212950
# 195080              H  2021-12-28       11212950
# 195081              Y  2021-12-28       11212950
#
# [195082 rows x 3 columns]

# %%
df.drop_duplicates()
# Out:
#        cpc_section_id patent_date  patent_number
# 0                   A  2020-01-07       10524409
# 1                   Y  2020-01-07       10524409
# 2                   A  2020-01-07       10524425
# 3                   B  2020-01-07       10524425
# 4                   G  2020-01-07       10524425
# ...               ...         ...            ...
# 195077              H  2021-12-28       11212938
# 195078              Y  2021-12-28       11212938
# 195079              G  2021-12-28       11212950
# 195080              H  2021-12-28       11212950
# 195081              Y  2021-12-28       11212950
#
# [195082 rows x 3 columns]

# %%
df.groupby('patent_number').count()
# Out:
#                cpc_section_id  patent_date
# patent_number
# 10524409                    2            2
# 10524425                    4            4
# 10524426                    3            3
# 10524430                    3            3
# 10524432                    5            5
# ...                       ...          ...
# 11212898                    3            3
# 11212919                    2            2
# 11212921                    2            2
# 11212938                    3            3
# 11212950                    3            3
#
# [73246 rows x 2 columns]

# %%
df.groupby('patent_number').count().groupby('cpc_section_id').sum().sort_values(by="patent_date",ascending=False)
# Out:
#                 patent_date
# cpc_section_id
# 3                     89043
# 2                     69574
# 4                     30380
# 5                      5180
# 6                       762
# 7                       126
# 9                         9
# 8                         8

# %%
a = pd.DataFrame(data)
a
# Out:
#                 patent_date
# cpc_section_id
# 3                     89043
# 2                     69574
# 4                     30380
# 5                      5180
# 6                       762
# 7                       126
# 9                         9
# 8                         8

# %%
y = df.groupby('patent_number').count().groupby('cpc_section_id').sum().sort_values(by="patent_date",ascending=False).values.flatten().tolist()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
label = df.groupby('patent_number').count().groupby('cpc_section_id').sum().index.tolist()
index = np.arange(len(label))
count = df.groupby('patent_number').count().groupby('cpc_section_id').sum().values.flatten().tolist()

plt.bar(label, count)
plt.xticks(index, label, fontsize=15)
plt.show()

# %%
df.groupby('cpc_section_id').count()
# Out:
#                 patent_number
# cpc_section_id
# A                        7567
# B                       25116
# C                       13622
# D                         892
# E                        2925
# F                       18101
# G                       19023
# H                       34590
# Y                       73246

# %%
df.groupby('cpc_section_id').count().index.values
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'Y'], dtype=object)

# %%
df.groupby('cpc_section_id').count().values.flatten()
# Out:
# array([ 7567, 25116, 13622,   892,  2925, 18101, 19023, 34590, 73246])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
label = df.groupby('cpc_section_id').count().index.values.tolist()
index = np.arange(len(label))
count = df.groupby('cpc_section_id').count().values.flatten().tolist()

plt.bar(label, count)
plt.xticks(index, label, fontsize=15)
plt.show()
